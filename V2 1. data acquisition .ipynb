# %%
import snscrape.modules.twitter as stwitter
import pandas as pd
import numpy as np
import pickle as pkl

# %% [markdown]
# Extract Data for 2020

# %%
# Creating list to append tweet data to
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(stwitter.TwitterSearchScraper('plant based meat vegan meat lang:en since:2020-01-01 until:2021-01-01').get_items()):

    tweets_list.append([tweet.date, tweet.id, tweet.url, tweet.content, tweet.user.username, tweet.likeCount])

# Creating a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['datetime', 'id','url' ,'content', 'username', 'like_count'])
tweets_df.to_csv('tweets_2020_v2.csv', sep=',', index=False)
# Out:
# /var/folders/vl/msb_49ms6zn68_cx7zq3jx4w0000gn/T/ipykernel_10406/3922410474.py:7: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list.append([tweet.date, tweet.id, tweet.url, tweet.content, tweet.user.username, tweet.likeCount])

# %%
tweets_df
# Out:
#                        datetime                   id  \
# 0     2020-12-31 23:36:38+00:00  1344789593669861376
# 1     2020-12-31 23:33:17+00:00  1344788749402529792
# 2     2020-12-31 23:32:51+00:00  1344788639604121600
# 3     2020-12-31 23:32:24+00:00  1344788527272185856
# 4     2020-12-31 23:32:03+00:00  1344788438189441024
# ...                         ...                  ...
# 13581 2020-01-01 01:32:27+00:00  1212184780659396608
# 13582 2020-01-01 00:31:33+00:00  1212169452860522496
# 13583 2020-01-01 00:31:12+00:00  1212169364771950593
# 13584 2020-01-01 00:04:29+00:00  1212162642535763973
# 13585 2020-01-01 00:00:43+00:00  1212161696296517632
#
#                                                      url  \
# 0      https://twitter.com/Chaseyyx_/status/134478959...
# 1      https://twitter.com/Chaseyyx_/status/134478874...
# 2      https://twitter.com/Chaseyyx_/status/134478863...
# 3      https://twitter.com/Chaseyyx_/status/134478852...
# ...

# %% [markdown]
# Acquire data for 2021

# %%
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(stwitter.TwitterSearchScraper('plant based meat vegan meat lang:en since:2021-01-01 until:2022-01-01').get_items()):
    #if i>maxTweets:
        #break
    tweets_list2.append([tweet.date, tweet.id, tweet.url, tweet.content, tweet.user.username, tweet.likeCount])

# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['datetime', 'id','url' ,'content', 'username', 'like_count'])

# Export dataframe into a CSV
tweets_df2.to_csv('tweets_2021_v2.csv', sep=',', index=False)
# Out:
# /var/folders/vl/msb_49ms6zn68_cx7zq3jx4w0000gn/T/ipykernel_10406/3098047494.py:7: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list2.append([tweet.date, tweet.id, tweet.url, tweet.content, tweet.user.username, tweet.likeCount])

# %%
tweets_df2
# Out:
#                        datetime                   id  \
# 0     2021-12-31 20:34:15+00:00  1477015263614754821
# 1     2021-12-31 20:31:35+00:00  1477014593809571840
# 2     2021-12-31 17:14:28+00:00  1476964989609127938
# 3     2021-12-31 16:44:40+00:00  1476957488863920128
# 4     2021-12-31 16:12:47+00:00  1476949464288043016
# ...                         ...                  ...
# 10539 2021-01-01 03:30:02+00:00  1344848327918157824
# 10540 2021-01-01 01:39:05+00:00  1344820408768483328
# 10541 2021-01-01 01:36:42+00:00  1344819807200321541
# 10542 2021-01-01 01:06:20+00:00  1344812166134820864
# 10543 2021-01-01 00:01:10+00:00  1344795764527161344
#
#                                                      url  \
# 0      https://twitter.com/LexShae/status/14770152636...
# 1      https://twitter.com/bclj199/status/14770145938...
# 2      https://twitter.com/BoboBenny/status/147696498...
# 3      https://twitter.com/jj27vv/status/147695748886...
# ...

# %% [markdown]
# Acquire data for 2022

# %%
tweets_list3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(stwitter.TwitterSearchScraper('plant based meat vegan meat lang:en since:2022-01-01 until:2022-10-14').get_items()):
    #if i>maxTweets:
        #break
    tweets_list3.append([tweet.date, tweet.id, tweet.url, tweet.content, tweet.user.username, tweet.likeCount])

# Creating a dataframe from the tweets list above
tweets_df3 = pd.DataFrame(tweets_list3, columns=['datetime', 'id','url' ,'content', 'username', 'like_count'])

# Export dataframe into a CSV
tweets_df3.to_csv('tweets_2022_v2.csv', sep=',', index=False)
# Out:
# /var/folders/vl/msb_49ms6zn68_cx7zq3jx4w0000gn/T/ipykernel_10406/3439998065.py:7: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list3.append([tweet.date, tweet.id, tweet.url, tweet.content, tweet.user.username, tweet.likeCount])

# %%
tweets_df3
# Out:
#                       datetime                   id  \
# 0    2022-10-13 21:29:29+00:00  1580672095997919232
# 1    2022-10-13 20:50:35+00:00  1580662306706313217
# 2    2022-10-13 20:27:31+00:00  1580656502313844741
# 3    2022-10-13 20:16:44+00:00  1580653787777470464
# 4    2022-10-13 20:10:00+00:00  1580652092263632897
# ...                        ...                  ...
# 9445 2022-01-01 09:31:38+00:00  1477210901509980160
# 9446 2022-01-01 08:22:36+00:00  1477193527146659840
# 9447 2022-01-01 04:56:48+00:00  1477141737386790913
# 9448 2022-01-01 04:08:07+00:00  1477129483476172803
# 9449 2022-01-01 02:00:01+00:00  1477097246680309770
#
#                                                     url  \
# 0     https://twitter.com/froggattpj/status/15806720...
# 1     https://twitter.com/TheCoopInBham/status/15806...
# 2     https://twitter.com/luellensynergyq/status/158...
# 3     https://twitter.com/th3awkwardvegan/status/158...
# ...

# %% [markdown]
# Combine into one df

# %%
df_final = pd.concat([tweets_df, tweets_df2, tweets_df3], axis=0)
df_final
# Out:
#                       datetime                   id  \
# 0    2020-12-31 23:36:38+00:00  1344789593669861376
# 1    2020-12-31 23:33:17+00:00  1344788749402529792
# 2    2020-12-31 23:32:51+00:00  1344788639604121600
# 3    2020-12-31 23:32:24+00:00  1344788527272185856
# 4    2020-12-31 23:32:03+00:00  1344788438189441024
# ...                        ...                  ...
# 9445 2022-01-01 09:31:38+00:00  1477210901509980160
# 9446 2022-01-01 08:22:36+00:00  1477193527146659840
# 9447 2022-01-01 04:56:48+00:00  1477141737386790913
# 9448 2022-01-01 04:08:07+00:00  1477129483476172803
# 9449 2022-01-01 02:00:01+00:00  1477097246680309770
#
#                                                     url  \
# 0     https://twitter.com/Chaseyyx_/status/134478959...
# 1     https://twitter.com/Chaseyyx_/status/134478874...
# 2     https://twitter.com/Chaseyyx_/status/134478863...
# 3     https://twitter.com/Chaseyyx_/status/134478852...
# ...

# %% [markdown]
# Save to pickle file

# %%
df_final.to_pickle('tweets_final_v2.pkl')
