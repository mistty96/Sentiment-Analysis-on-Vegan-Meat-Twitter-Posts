# %%
import snscrape.modules.twitter as stwitter
import pandas as pd
import numpy as np
import pickle as pkl 
from datetime import datetime
import datetime as dt

# %%
df = pd.read_pickle('tweets_final_v2.pkl')
df
# Out:
#                       datetime                   id  \
# 0    2020-12-31 23:36:38+00:00  1344789593669861376
# 1    2020-12-31 23:33:17+00:00  1344788749402529792
# 2    2020-12-31 23:32:51+00:00  1344788639604121600
# 3    2020-12-31 23:32:24+00:00  1344788527272185856
# 4    2020-12-31 23:32:03+00:00  1344788438189441024
# ...                        ...                  ...
# 9445 2022-01-01 09:31:38+00:00  1477210901509980160
# 9446 2022-01-01 08:22:36+00:00  1477193527146659840
# 9447 2022-01-01 04:56:48+00:00  1477141737386790913
# 9448 2022-01-01 04:08:07+00:00  1477129483476172803
# 9449 2022-01-01 02:00:01+00:00  1477097246680309770
#
#                                                     url  \
# 0     https://twitter.com/Chaseyyx_/status/134478959...
# 1     https://twitter.com/Chaseyyx_/status/134478874...
# 2     https://twitter.com/Chaseyyx_/status/134478863...
# 3     https://twitter.com/Chaseyyx_/status/134478852...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33580 entries, 0 to 9449
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    33580 non-null  datetime64[ns, UTC]
#  1   id          33580 non-null  int64
#  2   url         33580 non-null  object
#  3   content     33580 non-null  object
#  4   username    33580 non-null  object
#  5   like_count  33580 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(2), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# Sort dates in order

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.sort_values(by='datetime', ascending= True, inplace = True)
df
# Out:
#                        datetime                   id  \
# 13585 2020-01-01 00:00:43+00:00  1212161696296517632
# 13584 2020-01-01 00:04:29+00:00  1212162642535763973
# 13583 2020-01-01 00:31:12+00:00  1212169364771950593
# 13582 2020-01-01 00:31:33+00:00  1212169452860522496
# 13581 2020-01-01 01:32:27+00:00  1212184780659396608
# ...                         ...                  ...
# 4     2022-10-13 20:10:00+00:00  1580652092263632897
# 3     2022-10-13 20:16:44+00:00  1580653787777470464
# 2     2022-10-13 20:27:31+00:00  1580656502313844741
# 1     2022-10-13 20:50:35+00:00  1580662306706313217
# 0     2022-10-13 21:29:29+00:00  1580672095997919232
#
#                                                      url  \
# 13585  https://twitter.com/helloamygarner/status/1212...
# 13584  https://twitter.com/Taertebjerg/status/1212162...
# 13583  https://twitter.com/plantpowercoupl/status/121...
# 13582  https://twitter.com/FurForceFive/status/121216...
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                        datetime                   id  \
# 0     2020-01-01 00:00:43+00:00  1212161696296517632
# 1     2020-01-01 00:04:29+00:00  1212162642535763973
# 2     2020-01-01 00:31:12+00:00  1212169364771950593
# 3     2020-01-01 00:31:33+00:00  1212169452860522496
# 4     2020-01-01 01:32:27+00:00  1212184780659396608
# ...                         ...                  ...
# 33575 2022-10-13 20:10:00+00:00  1580652092263632897
# 33576 2022-10-13 20:16:44+00:00  1580653787777470464
# 33577 2022-10-13 20:27:31+00:00  1580656502313844741
# 33578 2022-10-13 20:50:35+00:00  1580662306706313217
# 33579 2022-10-13 21:29:29+00:00  1580672095997919232
#
#                                                      url  \
# 0      https://twitter.com/helloamygarner/status/1212...
# 1      https://twitter.com/Taertebjerg/status/1212162...
# 2      https://twitter.com/plantpowercoupl/status/121...
# 3      https://twitter.com/FurForceFive/status/121216...
# ...

# %% [markdown]
# Check for duplicates

# %%
# Select all duplicate rows based on multiple column names in list
duplicated_df = df[df.duplicated(['datetime', 'content', 'username'])]
print("Duplicate Rows based on 3 columns are:", duplicated_df, sep='\n')
# Out:
# Duplicate Rows based on 3 columns are:
# Empty DataFrame
# Columns: [datetime, id, url, content, username, like_count]
# Index: []

# %% [markdown]
# Get rid of columns not needed for analysis

# %%
df.drop(['id'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33580 entries, 0 to 33579
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    33580 non-null  datetime64[ns, UTC]
#  1   url         33580 non-null  object
#  2   content     33580 non-null  object
#  3   username    33580 non-null  object
#  4   like_count  33580 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(1), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# Understand statistics on like counts

# %%
df.describe()
# Out:
#          like_count
# count  33580.000000
# mean       6.232847
# std       69.290670
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max     5344.000000

# %%
#final save for cleaned data 

df.to_pickle('df_clean.pkl')
